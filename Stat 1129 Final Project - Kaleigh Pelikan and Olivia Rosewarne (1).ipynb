# %%
import turtle
t = turtle.Turtle()
turtle.speed(0)

def draw_flag(length, height, fillcolor):
    t.begin_fill()
    t.color(fillcolor)
    t.forward(length)
    t.right(90)
    t.forward(height)
    t.right(90)
    t.forward(length)
    t.right(90)
    t.forward(height)
    t.right(90)
    t.end_fill()

def get_color(color):
    t.color(color)

def draw_rectangle(length, height,fillcolor):
    t.begin_fill()
    t.color(fillcolor)
    t.forward(length)
    t.right(90)
    t.forward(height)
    t.right(90)
    t.forward(length)
    t.right(90)
    t.forward(height)
    t.right(90)
    t.end_fill()

def draw_flagborder(length, height, linecolor):
    t.color(linecolor)
    t.forward(length)
    t.right(90)
    t.forward(height)
    t.right(90)
    t.forward(length)
    t.right(90)
    t.forward(height)
    t.right(90)

def draw_star(size,fillcolor):
    t.begin_fill()
    t.color(fillcolor)
    for i in range(5):
        t.forward(10)
        t.right(144)
    t.end_fill()
  
def draw_star_position1(x,y):
    t.penup()
    t.setx(x)
    t.sety(y)
    for i in range(6):
        t.penup()
        t.forward(29)
        t.pendown()
        print(draw_star(-10, "white"))
    t.pendown()

def draw_star_position2(x,y):
    t.penup()
    t.setx(x)
    t.sety(y)
    for i in range(5):
        t.penup()
        t.forward(29)
        t.pendown()
        print(draw_star(-10, "white"))
    t.pendown()
        
def main():
    print(draw_flag(380, 200, "red"))
    print(draw_flag(380, 184.6154, "white"))
    print(draw_flag(380, 169.2308, "red"))
    print(draw_flag(380, 153.8462, "white"))
    print(draw_flag(380, 138.4615, "red"))
    print(draw_flag(380, 123.0769, "white"))
    print(draw_flag(380, 107.6923, "red"))
    print(draw_flag(380, 92.3077, "white"))
    print(draw_flag(380, 76.9231, "red"))
    print(draw_flag(380, 61.5385, "white"))
    print(draw_flag(380, 46.1538, "red"))
    print(draw_flag(380, 30.7692, "white"))
    print(draw_flag(380, 15.3846, "red"))
    print(draw_rectangle(152, 107.7, "blue"))
    print(draw_flagborder(380,200,"black"))
    print(draw_star_position1(-30,-10))
    print(draw_star_position1(-30,-30))
    print(draw_star_position1(-30,-50))
    print(draw_star_position1(-30,-70))
    print(draw_star_position1(-30,-90))
    print(draw_star_position2(-15,-20))
    print(draw_star_position2(-15,-40))
    print(draw_star_position2(-15,-60))
    print(draw_star_position2(-15,-80))

if __name__ == "__main__":
    main()
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
